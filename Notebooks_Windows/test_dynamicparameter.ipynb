# %%
# %matplotlib inline
from igmm import DynamicParameter
from matplotlib import pyplot as plt
import numpy as np

# %%
x = DynamicParameter(0.2)

# %%
x.get_value()
# Out:
# 0.2

# %%
conf = {'init': 0.2, 'end':0.01, 'steps':100, 'function':'log'}
x=DynamicParameter(**conf)
conf['function'] = 'linear'
y=DynamicParameter(**conf)
plt.plot(x.values)
plt.hold(True)
plt.plot(y.values)

# %%
for i in range(150):
    plt.plot(i,x.get_value(),'or')
    plt.hold(True)
